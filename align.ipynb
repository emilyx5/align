# %% [markdown]
# # Alignment Marker
#
# Produces marks for easier image alignment on klayout
# Images must be high res (4912 px x 2684 px)

# %%
from align import *
from pathlib import Path
import numpy as np
import imageio.v3 as iio
import skimage.color
from skimage.draw import line,disk, set_color
import cv2
import skimage.filters
import matplotlib.pyplot as plt

# examples
s1 = "stack1_D1.tif"
s2 = "stack2_D3.tif"
s3 = "stack3_B4.tif"

root = Path(r"C:\Users\xxgra\Downloads\DR_chip1_stack123")
img = "stack2_D3.tif"

#saves img in same folder as original img, shows in output

run(str(root/Path(img)))
